# %%
import pandas as pd
import numpy as np

# %%
import corona_lib

# %%
total_cases = "https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_confirmed_global.csv&filename=time_series_covid19_confirmed_global.csv"
deaths_cases = "https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_deaths_global.csv&filename=time_series_covid19_deaths_global.csv"
recovered_cases = "https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_recovered_global.csv&filename=time_series_covid19_recovered_global.csv"

# %%
total = pd.read_csv(total_cases)
deaths = pd.read_csv(deaths_cases)
recovered = pd.read_csv(recovered_cases)

# %%
total = total.T
deaths = deaths.T
recovered = recovered.T

# %%
total = corona_lib.convert_dates_to_python(total)
deaths = corona_lib.convert_dates_to_python(deaths)
recovered = corona_lib.convert_dates_to_python(recovered)

# %%
total = corona_lib.df_initial_clean_up(total, ["Poland", "Italy", "Germany", "Spain", "Sweden", "US"])
deaths = corona_lib.df_initial_clean_up(deaths, ["Poland", "Italy", "Germany", "Spain", "Sweden", "US"])
recovered = corona_lib.df_initial_clean_up(recovered, ["Poland", "Italy", "Germany", "Spain", "Sweden", "US"])

# %%
total["Poland"]
# Out:
# 2020-01-23        0
# 2020-01-24        0
# 2020-01-25        0
# 2020-01-26        0
# 2020-01-27        0
#               ...
# 2020-04-19     9287
# 2020-04-20     9593
# 2020-04-21     9856
# 2020-04-22    10169
# 2020-04-23    10511
# Name: Poland, Length: 92, dtype: object

# %%
xvals = range(len(total_countires.loc[total_countires.index[-poland_days_ago_diagnosed:], "Poland"]))

# %%
total.index[-10:]
# Out:
# Index([2020-04-14, 2020-04-15, 2020-04-16, 2020-04-17, 2020-04-18, 2020-04-19,
#        2020-04-20, 2020-04-21, 2020-04-22, 2020-04-23],
#       dtype='object')

# %%
total
# Out:
#                         0        1        2        3        4    \
# Province/State          NaN      NaN      NaN      NaN      NaN
# Country/Region  Afghanistan  Albania  Algeria  Andorra   Angola
# Lat                      33  41.1533  28.0339  42.5063 -11.2027
# Long                     65  20.1683   1.6596   1.5218  17.8739
# 1/22/20                   0        0        0        0        0
# ...                     ...      ...      ...      ...      ...
# 4/19/20                 996      562     2629      713       24
# 4/20/20                1026      584     2718      717       24
# 4/21/20                1092      609     2811      717       24
# 4/22/20                1176      634     2910      723       25
# 4/23/20                1279      663     3007      723       25
#
#                                 5          6        7    \
# Province/State                  NaN        NaN      NaN
# Country/Region  Antigua and Barbuda  Argentina  Armenia
# ...

# %%
total_last10 = total.loc[total.index[-10:], "Poland"]

# %%
deaths_last10 = deaths.loc[deaths.index[-10:], "Poland"]

# %%
recovered_last10 = recovered.loc[recovered.index[-10:], "Poland"]

# %%
deaths_last10
# Out:
# 2020-04-14    263
# 2020-04-15    286
# 2020-04-16    314
# 2020-04-17    332
# 2020-04-18    347
# 2020-04-19    360
# 2020-04-20    380
# 2020-04-21    401
# 2020-04-22    426
# 2020-04-23    454
# Name: Poland, dtype: object

# %%
recovered_last10
# Out:
# 2020-04-14     618
# 2020-04-15     668
# 2020-04-16     774
# 2020-04-17     866
# 2020-04-18     981
# 2020-04-19    1040
# 2020-04-20    1133
# 2020-04-21    1297
# 2020-04-22    1513
# 2020-04-23    1740
# Name: Poland, dtype: object

# %%
active_last10 = total_last10 - (recovered_last10 + deaths_last10)

# %%
active_last10
# Out:
# 2020-04-14    6321
# 2020-04-15    6628
# 2020-04-16    6830
# 2020-04-17    7181
# 2020-04-18    7414
# 2020-04-19    7887
# 2020-04-20    8080
# 2020-04-21    8158
# 2020-04-22    8230
# 2020-04-23    8317
# Name: Poland, dtype: object

# %%
for column_name in total.iteritems():
    print(column_name)
#     print(content)
# Out:
# ('Poland', 2020-01-23        0
# 2020-01-24        0
# 2020-01-25        0
# 2020-01-26        0
# 2020-01-27        0
#               ...
# 2020-04-19     9287
# 2020-04-20     9593
# 2020-04-21     9856
# 2020-04-22    10169
# 2020-04-23    10511
# Name: Poland, Length: 92, dtype: object)
# ('Italy', 2020-01-23         0
# 2020-01-24         0
# 2020-01-25         0
# 2020-01-26         0
# 2020-01-27         0
#                ...
# 2020-04-19    178972
# 2020-04-20    181228
# 2020-04-21    183957
# 2020-04-22    187327
# 2020-04-23    189973
# Name: Italy, Length: 92, dtype: object)
# ('Germany', 2020-01-23         0
# 2020-01-24         0
# 2020-01-25         0
# 2020-01-26         0
# 2020-01-27         1
#                ...
# 2020-04-19    145184
# 2020-04-20    147065
# 2020-04-21    148291
# 2020-04-22    150648
# 2020-04-23    153129
# Name: Germany, Length: 92, dtype: object)
# ('Spain', 2020-01-23         0
# 2020-01-24         0
# 2020-01-25         0
# ...
